# %%
import pandas as pd
import numpy as np

# %%
path = "/home/sejal/Documents/datascience/dataset/data/pima-diabetes-dataset/pima_indians_diabetes.csv"

# %%
df = pd.read_csv(path)

# %%
df.head(20)
# Out:
#     pregnant_times  glucose_tolerance_test  Diastolic_blood_pressure  \
# 0                6                     148                        72
# 1                1                      85                        66
# 2                8                     183                        64
# 3                1                      89                        66
# 4                0                     137                        40
# 5                5                     116                        74
# 6                3                      78                        50
# 7               10                     115                         0
# 8                2                     197                        70
# 9                8                     125                        96
# 10               4                     110                        92
# 11              10                     168                        74
# 12              10                     139                        80
# ...

# %%
df.describe()
# Out:
#        pregnant_times  glucose_tolerance_test  Diastolic_blood_pressure  \
# count      768.000000              768.000000                768.000000
# mean         3.845052              120.894531                 69.105469
# std          3.369578               31.972618                 19.355807
# min          0.000000                0.000000                  0.000000
# 25%          1.000000               99.000000                 62.000000
# 50%          3.000000              117.000000                 72.000000
# 75%          6.000000              140.250000                 80.000000
# max         17.000000              199.000000                122.000000
#
#        Triceps_skin_fold_thickness  serum_insulin  Body_mass_index  \
# count                   768.000000     768.000000       768.000000
# mean                     20.536458      79.799479        31.992578
# std                      15.952218     115.244002         7.884160
# ...

# %%
df.groupby("Class_variable").size()
# Out:
# Class_variable
# 0    500
# 1    268
# dtype: int64
