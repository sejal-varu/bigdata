# %%
import nltk
import codecs
from nltk.tokenize import PunktSentenceTokenizer,sent_tokenize, word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
def load_tsv(path):
    return pd.read_csv(path, sep='\t',encoding="utf-8")

# %%
path = "/home/sejal/Documents/datascience/dataset/data/Quora/quora_duplicate_questions.tsv"

# %%
original = load_tsv(path)

# %%
original.head(10)
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
# 5   5    11    12  Astrology: I am a Capricorn Sun Cap moon and c...
# 6   6    13    14                                Should I buy tiago?
# 7   7    15    16                     How can I be a good geologist?
# 8   8    17    18                    When do you use シ instead of し?
# 9   9    19    20  Motorola (company): Can I hack my Charter Moto...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0
# 5  I'm a triple Capricorn (Sun, Moon and ascendan...             1
# 6  What keeps childern active and far from phone ...             0
# 7          What should I do to be a great geologist?             1
# 8              When do you use "&" instead of "and"?             0
# 9  How do I hack Motorola DCX3400 for free internet?             0

# %%
def clean_data(sentence):
    filtered_sent = []
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words("english"))
    words = word_tokenize(sentence)
    for w in words:
        if w not in stop_words:
            filtered_sent.append(lemmatizer.lemmatize(w))
    return filtered_sent

# %%
tmp = pd.DataFrame()
df = original.head(50)

# %%
df["question1"] = df["question1"].apply(clean_data)
# Out:
# /home/sejal/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df["question2"] = df["question2"].apply(clean_data)
# Out:
# /home/sejal/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#     id  qid1  qid2                                          question1  \
# 0    0     1     2  [What, step, step, guide, invest, share, marke...
# 1    1     3     4  [What, story, Kohinoor, (, Koh-i-Noor, ), Diam...
# 2    2     5     6  [How, I, increase, speed, internet, connection...
# 3    3     7     8    [Why, I, mentally, lonely, ?, How, I, solve, ?]
# 4    4     9    10  [Which, one, dissolve, water, quikly, sugar, ,...
# 5    5    11    12  [Astrology, :, I, Capricorn, Sun, Cap, moon, c...
# 6    6    13    14                         [Should, I, buy, tiago, ?]
# 7    7    15    16                       [How, I, good, geologist, ?]
# 8    8    17    18                      [When, use, シ, instead, し, ?]
# 9    9    19    20  [Motorola, (, company, ), :, Can, I, hack, Cha...
# 10  10    21    22  [Method, find, separation, slit, using, fresne...
# 11  11    23    24          [How, I, read, find, YouTube, comment, ?]
# 12  12    25    26              [What, make, Physics, easy, learn, ?]
# 13  13    27    28         [What, first, sexual, experience, like, ?]
# 14  14    29    30  [What, law, change, status, student, visa, gre...
# 15  15    31    32  [What, would, Trump, presidency, mean, current...
# 16  16    33    34                      [What, manipulation, mean, ?]
# 17  17    35    36          [Why, girl, want, friend, guy, reject, ?]
# 18  18    37    38  [Why, many, Quora, user, posting, question, re...
# 19  19    39    40  [Which, best, digital, marketing, institution,...
# 20  20    41    42                      [Why, rocket, look, white, ?]
# 21  21    43    44           [What, 's, causing, someone, jealous, ?]
# 22  22    45    46                    [What, question, ask, Quora, ?]
# 23  23    47    48                         [How, much, 30, kV, HP, ?]
# 24  24    49    50  [What, mean, every, time, I, look, clock, numb...
# 25  25    51    52  [What, tip, making, job, interview, process, M...
# 26  26    53    54                        [What, web, application, ?]
# 27  27    55    56  [Does, society, place, much, importance, sport...
# 28  28    57    58          [What, best, way, make, money, online, ?]
# 29  29    59    60               [How, I, prepare, CA, final, law, ?]
# 30  30    61    62     [What, 's, one, thing, would, like, better, ?]
# 31  31    63    64  [What, special, care, someone, nose, get, stuf...
# 32  32    65    66  [What, Game, Thrones, villain, would, likely, ...
# 33  33    67    68  [Does, United, States, government, still, blac...
# 34  34    69    70            [What, best, travel, website, spain, ?]
# 35  35    71    72  [Why, people, think, Obama, try, take, gun, aw...
# 36  36    73    74  [I, 'm, 19-year-old, ., How, I, improve, skill...
# 37  37    75    76  [When, girlfriend, asks, boyfriend, ``, Why, c...
# 38  38    77    78                            [How, prepare, UPSC, ?]
# 39  39    79    80  [What, stall, speed, AOA, f-14, wing, fully, s...
# 40  40    81    82                             [Why, Slavs, squat, ?]
# 41  41    83    84  [When, I, expect, Cognizant, confirmation, mai...
# 42  42    85    86     [Can, I, make, 50,000, month, day, trading, ?]
# 43  43    87    88        [Is, good, kid, rebel, worth, long, run, ?]
# 44  44    89    90  [What, university, Rexnord, recruit, new, grad...
# 45  45    91    92  [What, quickest, way, increase, Instagram, fol...
# 46  46    93    94  [How, Darth, Vader, fought, Darth, Maul, Star,...
# 47  47    95    96  [What, stage, breaking, couple, ?, I, mean, ,,...
# 48  48    97    98      [What, example, product, make, crude, oil, ?]
# 49  49    99   100                          [How, I, make, friend, .]
#
#                                             question2  is_duplicate
# 0   [What, step, step, guide, invest, share, marke...             0
# 1   [What, would, happen, Indian, government, stol...             0
# 2   [How, Internet, speed, increased, hacking, DNS...             0
# 3   [Find, remainder, [, math, ], 23^, {, 24, }, [...             0
# 4       [Which, fish, would, survive, salt, water, ?]             0
# 5   [I, 'm, triple, Capricorn, (, Sun, ,, Moon, as...             1
# 6   [What, keep, childern, active, far, phone, vid...             0
# 7                      [What, I, great, geologist, ?]             1
# 8          [When, use, ``, &, '', instead, ``, '', ?]             0
# 9   [How, I, hack, Motorola, DCX3400, free, intern...             0
# 10  [What, thing, technician, tell, durability, re...             0
# 11                 [How, I, see, Youtube, comment, ?]             1
# 12                [How, make, physic, easy, learn, ?]             1
# 13               [What, first, sexual, experience, ?]             1
# 14  [What, law, change, status, student, visa, gre...             0
# 15  [How, Trump, presidency, affect, student, pres...             1
# 16                      [What, manipulation, mean, ?]             1
# 17               [How, guy, feel, rejecting, girl, ?]             0
# 18  [Why, people, ask, Quora, question, answered, ...             1
# 19  [Which, best, digital, marketing, institute, P...             0
# 20          [Why, rocket, booster, painted, white, ?]             1
# 21              [What, I, avoid, jealous, someone, ?]             0
# 22                [Which, question, I, ask, Quora, ?]             0
# 23  [Where, I, find, conversion, chart, CC, horsep...             0
# 24  [How, many, time, day, clock, ’, hand, overlap...             0
# 25  [What, tip, making, job, interview, process, F...             0
# 26             [What, web, application, framework, ?]             0
# 27               [How, sport, contribute, society, ?]             0
# 28           [What, best, way, ask, money, online, ?]             0
# 29  [How, one, know, he/she, completely, prepare, ...             1
# 30  [What, 's, one, thing, despite, knowing, bette...             0
# 31    [How, I, keep, nose, getting, stuffy, night, ?]             1
# 32  [What, Game, Thrones, villain, would, like, me...             1
# 33  [How, average, speed, gas, molecule, determine...             0
# 34                   [What, best, travel, website, ?]             0
# 35  [Has, gun, control, initiative, take, away, gu...             0
# 36  [I, 19, year, old, guy, ., How, I, become, bil...             0
# 37  [My, girlfriend, said, end, confused, feeling,...             0
# 38               [How, I, prepare, civil, service, ?]             1
# 39  [Why, aircraft, stop, using, variable-sweep, w...             0
# 40               [Will, squat, make, leg, thicker, ?]             0
# 41  [When, I, expect, Cognizant, confirmation, mai...             0
# 42     [Can, I, make, 30,000, month, day, trading, ?]             0
# 43                          [Is, bored, good, kid, ?]             0
# 44  [What, university, B, &, G, Foods, recruit, ne...             0
# 45    [How, increase, number, Instagram, follower, ?]             0
# 46  [Does, Quora, character, limit, profile, descr...             0
# 47          [Who, affected, breakup, ,, boy, girl, ?]             0
# 48               [What, product, made, crude, oil, ?]             1
# 49                             [How, make, friend, ?]             1
