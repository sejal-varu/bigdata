# %%
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
import pandas as pd
# %matplotlib inline
from sklearn.datasets import make_classification

# %%
z = np.linspace(-2, 2, 1000)
z_predict = 1/(1+np.exp(-z))

# %%
plt.figure(figsize=(10,6))
plt.plot(z, z_predict)
#plt.plot(z, z_predict)
plt.show()

# %%
import pandas as pd
import numpy as np
