# %%
#plt sqqrt x graph anf lox graph
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#Use https://matplotlib.org for more functions

x= 10

# %%
sq = np.sqrt(x)
lg = np.log(x)
lst = [2,3,10,50,100]
print np.log(lst)
'''
for n in lst:
    print np.log(n) 
print "/n"
for n in lst:
    print  np.sqrt(n)

'''
plt.plot([np.sqrt(lst), np.log(lst)])
plt.show()
# Out:
# [0.69314718 1.09861229 2.30258509 3.91202301 4.60517019]
